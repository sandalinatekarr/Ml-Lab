# %%
# !pip install numpy pandas matplotlib scikit-learn

# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.svm import SVC

# %%
df = pd.read_csv('Solar_radiation_classification.csv')
df
# Out:
#       Air Temperature (C°)  Air Temperature Uncertainty (C°)  \
# 0                 1.598833                         -0.039841
# 1                 1.415552                         -0.039841
# 2                 1.034891                         -0.039841
# 3                 0.174880                         -0.039841
# 4                -0.572343                         -0.039841
# ...                    ...                               ...
# 1257             -0.078894                         -0.039841
# 1258             -0.177584                         -0.039841
# 1259              0.865709                         -0.039841
# 1260              1.105384                         -0.039841
# 1261              1.387355                         -0.039841
#
#       Wind Direction at 3m (°N)  Wind Direction at 3m Uncertainty (°N)  \
# 0                     -1.358521                               0.163933
# 1                     -1.333544                               0.163933
# ...

# %%
# Remove regression column and retain classification column
df.drop(['GHI (Wh/m2)'], axis=1, inplace=True)
df.columns
# Out:
# Index(['Air Temperature (C°)', 'Air Temperature Uncertainty (C°)',
#        'Wind Direction at 3m (°N)', 'Wind Direction at 3m Uncertainty (°N)',
#        'Wind Speed at 3m (m/s)', 'Wind Speed at 3m Uncertainty (m/s)',
#        'Wind Speed at 3m (std dev) (m/s)', 'DHI (Wh/m2)',
#        'DHI Uncertainty (Wh/m2)', 'Standard Deviation DHI (Wh/m2)',
#        'DNI (Wh/m2)', 'DNI Uncertainty (Wh/m2)',
#        'Standard Deviation DNI (Wh/m2)', 'GHI Uncertainty (Wh/m2)',
#        'Standard Deviation GHI (Wh/m2)', 'Peak Wind Speed at 3m (m/s)',
#        'Peak Wind Speed at 3m Uncertainty (m/s)', 'Relative Humidity (%)',
#        'Relative Humidity Uncertainty (%)',
#        'Barometric Pressure (mB (hPa equiv))',
#        'Barometric Pressure Uncertainty (mB (hPa equiv))', 'Class'],
#       dtype='object')

# %%
y = df.pop('Class').values
X = df.values

print('Number of examples: ', X.shape[0])
print('Number of variables: ', X.shape[1])
# Out:
# Number of examples:  1262
# Number of variables:  21

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)
print('Number of training examples: ', X_train.shape[0])
print('Number of testing examples: ', X_test.shape[0])
# Out:
# Number of training examples:  1009
# Number of testing examples:  253

# %%
clf = SVC(C=1.0, kernel='rbf', degree=2, gamma='scale')
clf.fit(X_train, y_train)
# Out:
# SVC(degree=2)

# %%
# ?SVC
# Out:
# Init signature:
# SVC(
#     *,
#     C=1.0,
#     kernel='rbf',
#     degree=3,
#     gamma='scale',
#     coef0=0.0,
#     shrinking=True,
#     probability=False,
#     tol=0.001,
#     cache_size=200,
#     class_weight=None,
#     verbose=False,
#     max_iter=-1,
#     decision_function_shape='ovr',
#     break_ties=False,
#     random_state=None,
# )
# Docstring:
# C-Support Vector Classification.
#
# The implementation is based on libsvm. The fit time scales at least
# quadratically with the number of samples and may be impractical
# beyond tens of thousands of samples. For large datasets
# consider using :class:`~sklearn.svm.LinearSVC` or
# :class:`~sklearn.linear_model.SGDClassifier` instead, possibly after a
# :class:`~sklearn.kernel_approximation.Nystroem` transformer or
# other :ref:`kernel_approximation`.
#
# The multiclass support is handled according to a one-vs-one scheme.
#
# For details on the precise mathematical formulation of the provided
# ...

# %%
y_test_pred = clf.predict(X_test)
y_test_pred
# Out:
# array(['Monitoring', 'Monitoring', 'Inspecting', 'Monitoring',
#        'Inspecting', 'Monitoring', 'Monitoring', 'Monitoring', 'Running',
#        'Monitoring', 'Monitoring', 'Running', 'Running', 'Inspecting',
#        'Running', 'Running', 'Monitoring', 'Inspecting', 'Running',
#        'Monitoring', 'Monitoring', 'Monitoring', 'Monitoring',
#        'Inspecting', 'Running', 'Inspecting', 'Monitoring', 'Inspecting',
#        'Monitoring', 'Monitoring', 'Running', 'Monitoring', 'Monitoring',
#        'Monitoring', 'Monitoring', 'Running', 'Running', 'Monitoring',
#        'Running', 'Monitoring', 'Monitoring', 'Running', 'Monitoring',
#        'Running', 'Running', 'Running', 'Monitoring', 'Running',
#        'Running', 'Monitoring', 'Monitoring', 'Inspecting', 'Running',
#        'Monitoring', 'Running', 'Monitoring', 'Running', 'Running',
#        'Monitoring', 'Monitoring', 'Monitoring', 'Running', 'Monitoring',
# ...

# %% [markdown]
# ### Measure accuracy

# %%
y_train_pred = clf.predict(X_train)
acc = sum(y_train_pred == y_train)/y_train_pred.shape[0] *100
print('Training accuracy: {0:2.2f}%'.format(acc))
# Out:
# Training accuracy: 94.95%

# %%
acc = sum(y_test_pred == y_test)/y_test_pred.shape[0] *100
print('Testing accuracy: {0:2.2f}%'.format(acc))
# Out:
# Testing accuracy: 92.89%

# %%
clf.n_support_, clf.classes_
# Out:
# (array([117, 267, 158]),
#  array(['Inspecting', 'Monitoring', 'Running'], dtype=object))

# %%
clf.support_
# Out:
# array([   3,   20,   22,   24,   32,   40,   49,   50,   51,   53,   54,
#          69,   70,   75,   80,   95,  118,  141,  159,  160,  162,  167,
#         185,  202,  205,  232,  238,  247,  254,  255,  256,  257,  259,
#         279,  281,  291,  298,  305,  306,  328,  351,  356,  364,  369,
#         378,  389,  393,  401,  402,  423,  457,  466,  469,  477,  486,
#         494,  495,  523,  526,  530,  534,  541,  542,  556,  574,  582,
#         584,  588,  599,  603,  605,  607,  623,  632,  638,  644,  657,
#         667,  669,  680,  681,  682,  691,  695,  696,  700,  702,  715,
#         723,  739,  746,  747,  756,  763,  773,  775,  784,  792,  794,
#         809,  814,  829,  833,  847,  849,  857,  873,  883,  896,  900,
#         904,  908,  927,  943,  953,  977,  985,    0,    1,    4,   12,
#          14,   19,   27,   28,   30,   37,   38,   41,   42,   46,   55,
#          58,   59,   67,   68,   73,   76,   84,   85,   89,   94,   99,
# ...

# %%
clf.support_vectors_
# Out:
# array([[-1.07989059, -0.03984095,  1.2558075 , ..., -0.04948017,
#         -0.59347289, -0.7833155 ],
#        [-0.03659813, -0.03984095, -1.30856588, ..., -0.04948017,
#          0.99883342,  0.89218308],
#        [-0.02249958, -0.03984095,  0.05687969, ..., -0.04948017,
#          1.24413466,  1.31105772],
#        ...,
#        [ 0.17488007, -0.03984095,  0.8561649 , ..., -0.04948017,
#         -2.33640278, -2.45881408],
#        [ 0.56963938, -0.03984095, -1.47508363, ..., -0.04948017,
#          0.88909339,  0.89218308],
#        [ 0.80931468, -0.03984095, -1.20032934, ..., -0.04948017,
#         -0.87965768, -0.7833155 ]])

# %%
clf.decision_function
# Out:
# <bound method BaseSVC.decision_function of SVC(degree=2)>
